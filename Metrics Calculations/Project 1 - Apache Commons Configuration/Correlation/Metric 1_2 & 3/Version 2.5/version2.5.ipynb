# %%
import pandas as pd

# %%
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('jacoco.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['StatementCoverage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['BranchCoverage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CodeComplexity'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.plot(x='CodeComplexity', y='StatementCoverage', style='o')

# %%
df_collection.plot(x='CodeComplexity', y='BranchCoverage', style='o')

# %%
plt.scatter(df_collection['CodeComplexity'], df_collection['StatementCoverage'])

# %%
plt.show()

# %%
df_collection.corr(method ='spearman')
# Out:
#                      INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED             1.000000             0.427753       0.746674
# INSTRUCTION_COVERED            0.427753             1.000000       0.563624
# BRANCH_MISSED                  0.746674             0.563624       1.000000
# BRANCH_COVERED                 0.439550             0.887635       0.616005
# LINE_MISSED                    0.866589             0.380673       0.625630
# LINE_COVERED                   0.406749             0.965580       0.542130
# COMPLEXITY_MISSED              0.898636             0.447616       0.859186
# COMPLEXITY_COVERED             0.352580             0.924878       0.483930
# METHOD_MISSED                  0.637153             0.048127       0.287317
# METHOD_COVERED                 0.330895             0.844272       0.402427
# StatementCoverage             -0.827855            -0.249449      -0.537312
# BranchCoverage                -0.767649            -0.227425      -0.939584
# CodeComplexity                 0.531686             0.914261       0.630492
#
#                      BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED         0.439550     0.866589      0.406749
# INSTRUCTION_COVERED        0.887635     0.380673      0.965580
# BRANCH_MISSED              0.616005     0.625630      0.542130
# BRANCH_COVERED             1.000000     0.422855      0.892052
# LINE_MISSED                0.422855     1.000000      0.411276
# LINE_COVERED               0.892052     0.411276      1.000000
# COMPLEXITY_MISSED          0.485984     0.792239      0.426010
# COMPLEXITY_COVERED         0.886718     0.378113      0.963167
# METHOD_MISSED              0.058612     0.682357      0.051751
# METHOD_COVERED             0.725155     0.361978      0.896425
# StatementCoverage         -0.308373    -0.972625     -0.283712
# BranchCoverage            -0.214883    -0.604675     -0.189481
# CodeComplexity             0.887893     0.517744      0.937713
#
#                      COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED            0.898636            0.352580       0.637153
# INSTRUCTION_COVERED           0.447616            0.924878       0.048127
# BRANCH_MISSED                 0.859186            0.483930       0.287317
# BRANCH_COVERED                0.485984            0.886718       0.058612
# LINE_MISSED                   0.792239            0.378113       0.682357
# LINE_COVERED                  0.426010            0.963167       0.051751
# COMPLEXITY_MISSED             1.000000            0.382958       0.647109
# COMPLEXITY_COVERED            0.382958            1.000000       0.043517
# METHOD_MISSED                 0.647109            0.043517       1.000000
# METHOD_COVERED                0.333922            0.944330       0.051693
# StatementCoverage            -0.762408           -0.258195      -0.734757
# BranchCoverage               -0.876082           -0.087686      -0.415787
# CodeComplexity                0.566294            0.953367       0.206969
#
#                      METHOD_COVERED  StatementCoverage  BranchCoverage  \
# INSTRUCTION_MISSED         0.330895          -0.827855       -0.767649
# INSTRUCTION_COVERED        0.844272          -0.249449       -0.227425
# BRANCH_MISSED              0.402427          -0.537312       -0.939584
# BRANCH_COVERED             0.725155          -0.308373       -0.214883
# LINE_MISSED                0.361978          -0.972625       -0.604675
# LINE_COVERED               0.896425          -0.283712       -0.189481
# COMPLEXITY_MISSED          0.333922          -0.762408       -0.876082
# COMPLEXITY_COVERED         0.944330          -0.258195       -0.087686
# METHOD_MISSED              0.051693          -0.734757       -0.415787
# METHOD_COVERED             1.000000          -0.247800       -0.064701
# StatementCoverage         -0.247800           1.000000        0.602415
# BranchCoverage            -0.064701           0.602415        1.000000
# CodeComplexity             0.895868          -0.409473       -0.317106
#
#                      CodeComplexity
# INSTRUCTION_MISSED         0.531686
# INSTRUCTION_COVERED        0.914261
# BRANCH_MISSED              0.630492
# BRANCH_COVERED             0.887893
# LINE_MISSED                0.517744
# LINE_COVERED               0.937713
# COMPLEXITY_MISSED          0.566294
# COMPLEXITY_COVERED         0.953367
# METHOD_MISSED              0.206969
# METHOD_COVERED             0.895868
# StatementCoverage         -0.409473
# BranchCoverage            -0.317106
# CodeComplexity             1.000000

# %%
df_collection[['CodeComplexity','StatementCoverage']].corr(method ='spearman')
# Out:
#                    CodeComplexity  StatementCoverage
# CodeComplexity           1.000000          -0.409473
# StatementCoverage       -0.409473           1.000000

# %%
df_clean = df_collection.dropna()

# %%
stats.spearmanr(df_clean['StatementCoverage'], df_clean['CodeComplexity'])
# Out:
# SpearmanrResult(correlation=-0.40934108023560345, pvalue=2.3353133297409544e-09)

# %%
df_collection[['CodeComplexity','BranchCoverage']].corr(method ='spearman')
# Out:
#                 CodeComplexity  BranchCoverage
# CodeComplexity        1.000000       -0.317106
# BranchCoverage       -0.317106        1.000000

# %%
df_clean = df_collection.dropna()

# %%
stats.spearmanr(df_clean['BranchCoverage'], df_clean['CodeComplexity'])
# Out:
# SpearmanrResult(correlation=-0.31710627444963707, pvalue=5.620032351033281e-06)

# %%
print('Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Statment Coverage 89.32584269662921

# %%
print('Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Branch Coverage 82.76969178082192
