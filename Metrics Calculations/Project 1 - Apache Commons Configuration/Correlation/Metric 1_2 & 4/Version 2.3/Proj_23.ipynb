# %%
import pandas as pd

# %%
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('jacoco_23.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['StatementCoverage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['BranchCoverage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CodeComplexity'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.plot(x='CodeComplexity', y='StatementCoverage', style='o')

# %%
df_collection.plot(x='CodeComplexity', y='BranchCoverage', style='o')

# %%
plt.scatter(df_collection['CodeComplexity'], df_collection['StatementCoverage'])

# %%
plt.show()

# %%
df_collection.corr(method ='spearman')
# Out:
#                      INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED             1.000000             0.446790       0.730832
# INSTRUCTION_COVERED            0.446790             1.000000       0.565766
# BRANCH_MISSED                  0.730832             0.565766       1.000000
# BRANCH_COVERED                 0.459171             0.892200       0.617529
# LINE_MISSED                    0.907780             0.408273       0.672002
# LINE_COVERED                   0.448678             0.965501       0.568433
# COMPLEXITY_MISSED              0.890595             0.466481       0.858352
# COMPLEXITY_COVERED             0.407556             0.931020       0.514850
# METHOD_MISSED                  0.658468             0.067286       0.311610
# METHOD_COVERED                 0.398978             0.852153       0.449790
# Statement Coverage            -0.874755            -0.293377      -0.593458
# Branch Coverage               -0.036533             0.554699      -0.003308
# Code Complexity                0.559758             0.911871       0.633638
# StatementCoverage             -0.874755            -0.293377      -0.593458
# BranchCoverage                -0.733824            -0.253619      -0.935441
# CodeComplexity                 0.559758             0.911871       0.633638
#
#                      BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED         0.459171     0.907780      0.448678
# INSTRUCTION_COVERED        0.892200     0.408273      0.965501
# BRANCH_MISSED              0.617529     0.672002      0.568433
# BRANCH_COVERED             1.000000     0.443211      0.899755
# LINE_MISSED                0.443211     1.000000      0.436253
# LINE_COVERED               0.899755     0.436253      1.000000
# COMPLEXITY_MISSED          0.501323     0.821849      0.466792
# COMPLEXITY_COVERED         0.894067     0.398586      0.965187
# METHOD_MISSED              0.076375     0.671594      0.069704
# METHOD_COVERED             0.736783     0.381668      0.899953
# Statement Coverage        -0.341572    -0.976471     -0.325426
# Branch Coverage            0.669268    -0.006516      0.566866
# Code Complexity            0.886229     0.543190      0.942826
# StatementCoverage         -0.341572    -0.976471     -0.325426
# BranchCoverage            -0.241879    -0.656724     -0.253233
# CodeComplexity             0.886229     0.543190      0.942826
#
#                      COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED            0.890595            0.407556       0.658468
# INSTRUCTION_COVERED           0.466481            0.931020       0.067286
# BRANCH_MISSED                 0.858352            0.514850       0.311610
# BRANCH_COVERED                0.501323            0.894067       0.076375
# LINE_MISSED                   0.821849            0.398586       0.671594
# LINE_COVERED                  0.466792            0.965187       0.069704
# COMPLEXITY_MISSED             1.000000            0.433150       0.663174
# COMPLEXITY_COVERED            0.433150            1.000000       0.064500
# METHOD_MISSED                 0.663174            0.064500       1.000000
# METHOD_COVERED                0.399012            0.944951       0.068576
# Statement Coverage           -0.795046           -0.294893      -0.722147
# Branch Coverage              -0.062583            0.591601      -0.137469
# Code Complexity               0.590641            0.960170       0.234959
# StatementCoverage            -0.795046           -0.294893      -0.722147
# BranchCoverage               -0.869519           -0.150972      -0.431898
# CodeComplexity                0.590641            0.960170       0.234959
#
#                      METHOD_COVERED  Statement Coverage  Branch Coverage  \
# INSTRUCTION_MISSED         0.398978           -0.874755        -0.036533
# INSTRUCTION_COVERED        0.852153           -0.293377         0.554699
# BRANCH_MISSED              0.449790           -0.593458        -0.003308
# BRANCH_COVERED             0.736783           -0.341572         0.669268
# LINE_MISSED                0.381668           -0.976471        -0.006516
# LINE_COVERED               0.899953           -0.325426         0.566866
# COMPLEXITY_MISSED          0.399012           -0.795046        -0.062583
# COMPLEXITY_COVERED         0.944951           -0.294893         0.591601
# METHOD_MISSED              0.068576           -0.722147        -0.137469
# METHOD_COVERED             1.000000           -0.283558         0.449302
# Statement Coverage        -0.283558            1.000000         0.044071
# Branch Coverage            0.449302            0.044071         1.000000
# Code Complexity            0.907248           -0.451794         0.523949
# StatementCoverage         -0.283558            1.000000         0.044071
# BranchCoverage            -0.134994            0.648398         1.000000
# CodeComplexity             0.907248           -0.451794         0.523949
#
#                      Code Complexity  StatementCoverage  BranchCoverage  \
# INSTRUCTION_MISSED          0.559758          -0.874755       -0.733824
# INSTRUCTION_COVERED         0.911871          -0.293377       -0.253619
# BRANCH_MISSED               0.633638          -0.593458       -0.935441
# BRANCH_COVERED              0.886229          -0.341572       -0.241879
# LINE_MISSED                 0.543190          -0.976471       -0.656724
# LINE_COVERED                0.942826          -0.325426       -0.253233
# COMPLEXITY_MISSED           0.590641          -0.795046       -0.869519
# COMPLEXITY_COVERED          0.960170          -0.294893       -0.150972
# METHOD_MISSED               0.234959          -0.722147       -0.431898
# METHOD_COVERED              0.907248          -0.283558       -0.134994
# Statement Coverage         -0.451794           1.000000        0.648398
# Branch Coverage             0.523949           0.044071        1.000000
# Code Complexity             1.000000          -0.451794       -0.354548
# StatementCoverage          -0.451794           1.000000        0.648398
# BranchCoverage             -0.354548           0.648398        1.000000
# CodeComplexity              1.000000          -0.451794       -0.354548
#
#                      CodeComplexity
# INSTRUCTION_MISSED         0.559758
# INSTRUCTION_COVERED        0.911871
# BRANCH_MISSED              0.633638
# BRANCH_COVERED             0.886229
# LINE_MISSED                0.543190
# LINE_COVERED               0.942826
# COMPLEXITY_MISSED          0.590641
# COMPLEXITY_COVERED         0.960170
# METHOD_MISSED              0.234959
# METHOD_COVERED             0.907248
# Statement Coverage        -0.451794
# Branch Coverage            0.523949
# Code Complexity            1.000000
# StatementCoverage         -0.451794
# BranchCoverage            -0.354548
# CodeComplexity             1.000000

# %%
df_collection[['CodeComplexity','StatementCoverage']].corr(method ='spearman')
# Out:
#                    CodeComplexity  StatementCoverage
# CodeComplexity           1.000000          -0.451794
# StatementCoverage       -0.451794           1.000000

# %%
df_clean = df_collection.dropna()

# %%
stats.spearmanr(df_clean['StatementCoverage'], df_clean['CodeComplexity'])
# Out:
# SpearmanrResult(correlation=-0.40545386607383427, pvalue=4.9356539693360566e-09)

# %%
df_collection[['CodeComplexity','BranchCoverage']].corr(method ='spearman')
# Out:
#                 CodeComplexity  BranchCoverage
# CodeComplexity        1.000000       -0.354548
# BranchCoverage       -0.354548        1.000000

# %%
df_clean = df_collection.dropna()

# %%
stats.spearmanr(df_clean['BranchCoverage'], df_clean['CodeComplexity'])
# Out:
# SpearmanrResult(correlation=-0.3545476356861214, pvalue=4.2180448857686624e-07)

# %%
print('Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Statment Coverage 89.28756253234431

# %%
print('Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Branch Coverage 83.27510917030567
