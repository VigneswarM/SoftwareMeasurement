# %%
import pandas as pd

# %%
import scipy.stats  as stats

# %%
df_collection = pd.read_csv('jacoco_24.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection['StatementCoverage'] =  (df_collection['LINE_COVERED'] / (df_collection['LINE_COVERED'] + df_collection['LINE_MISSED'])) * 100

# %%
df_collection['BranchCoverage'] =  (df_collection['BRANCH_COVERED'] / (df_collection['BRANCH_COVERED'] + df_collection['BRANCH_MISSED'])) * 100

# %%
df_collection['CodeComplexity'] =  df_collection['COMPLEXITY_COVERED'] + df_collection['COMPLEXITY_MISSED'];

# %%
df_collection.plot(x='CodeComplexity', y='StatementCoverage', style='o')

# %%
df_collection.plot(x='CodeComplexity', y='BranchCoverage', style='o')

# %%
plt.scatter(df_collection['CodeComplexity'], df_collection['StatementCoverage'])

# %%
plt.show()

# %%
df_collection.corr(method ='spearman')
# Out:
#                      INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED             1.000000             0.432204       0.751179
# INSTRUCTION_COVERED            0.432204             1.000000       0.563619
# BRANCH_MISSED                  0.751179             0.563619       1.000000
# BRANCH_COVERED                 0.444723             0.887693       0.615800
# LINE_MISSED                    0.866406             0.387881       0.631029
# LINE_COVERED                   0.410154             0.965583       0.542309
# COMPLEXITY_MISSED              0.899243             0.454329       0.863222
# COMPLEXITY_COVERED             0.355218             0.924525       0.483831
# METHOD_MISSED                  0.626914             0.046667       0.282372
# METHOD_COVERED                 0.331777             0.844075       0.402598
# StatementCoverage             -0.829374            -0.260315      -0.546062
# BranchCoverage                -0.768568            -0.228147      -0.939397
# CodeComplexity                 0.534778             0.914142       0.630782
#
#                      BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED         0.444723     0.866406      0.410154
# INSTRUCTION_COVERED        0.887693     0.387881      0.965583
# BRANCH_MISSED              0.615800     0.631029      0.542309
# BRANCH_COVERED             1.000000     0.430225      0.892709
# LINE_MISSED                0.430225     1.000000      0.417411
# LINE_COVERED               0.892709     0.417411      1.000000
# COMPLEXITY_MISSED          0.491581     0.791507      0.432291
# COMPLEXITY_COVERED         0.887199     0.384005      0.963051
# METHOD_MISSED              0.055569     0.671664      0.049029
# METHOD_COVERED             0.725905     0.366296      0.896194
# StatementCoverage         -0.318790    -0.973560     -0.293709
# BranchCoverage            -0.215543    -0.604080     -0.190190
# CodeComplexity             0.888287     0.523499      0.937741
#
#                      COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED            0.899243            0.355218       0.626914
# INSTRUCTION_COVERED           0.454329            0.924525       0.046667
# BRANCH_MISSED                 0.863222            0.483831       0.282372
# BRANCH_COVERED                0.491581            0.887199       0.055569
# LINE_MISSED                   0.791507            0.384005       0.671664
# LINE_COVERED                  0.432291            0.963051       0.049029
# COMPLEXITY_MISSED             1.000000            0.388996       0.636514
# COMPLEXITY_COVERED            0.388996            1.000000       0.040908
# METHOD_MISSED                 0.636514            0.040908       1.000000
# METHOD_COVERED                0.339232            0.944385       0.047494
# StatementCoverage            -0.762042           -0.267854      -0.726760
# BranchCoverage               -0.876366           -0.088228      -0.407828
# CodeComplexity                0.571857            0.953195       0.204864
#
#                      METHOD_COVERED  StatementCoverage  BranchCoverage  \
# INSTRUCTION_MISSED         0.331777          -0.829374       -0.768568
# INSTRUCTION_COVERED        0.844075          -0.260315       -0.228147
# BRANCH_MISSED              0.402598          -0.546062       -0.939397
# BRANCH_COVERED             0.725905          -0.318790       -0.215543
# LINE_MISSED                0.366296          -0.973560       -0.604080
# LINE_COVERED               0.896194          -0.293709       -0.190190
# COMPLEXITY_MISSED          0.339232          -0.762042       -0.876366
# COMPLEXITY_COVERED         0.944385          -0.267854       -0.088228
# METHOD_MISSED              0.047494          -0.726760       -0.407828
# METHOD_COVERED             1.000000          -0.255800       -0.065183
# StatementCoverage         -0.255800           1.000000        0.601709
# BranchCoverage            -0.065183           0.601709        1.000000
# CodeComplexity             0.895749          -0.419048       -0.317761
#
#                      CodeComplexity
# INSTRUCTION_MISSED         0.534778
# INSTRUCTION_COVERED        0.914142
# BRANCH_MISSED              0.630782
# BRANCH_COVERED             0.888287
# LINE_MISSED                0.523499
# LINE_COVERED               0.937741
# COMPLEXITY_MISSED          0.571857
# COMPLEXITY_COVERED         0.953195
# METHOD_MISSED              0.204864
# METHOD_COVERED             0.895749
# StatementCoverage         -0.419048
# BranchCoverage            -0.317761
# CodeComplexity             1.000000

# %%
df_collection[['CodeComplexity','StatementCoverage']].corr(method ='spearman')
# Out:
#                    CodeComplexity  StatementCoverage
# CodeComplexity           1.000000          -0.419048
# StatementCoverage       -0.419048           1.000000

# %%
df_clean = df_collection.dropna()

# %%
stats.spearmanr(df_clean['StatementCoverage'], df_clean['CodeComplexity'])
# Out:
# SpearmanrResult(correlation=-0.40921267008211404, pvalue=2.3649412587043863e-09)

# %%
df_collection[['CodeComplexity','BranchCoverage']].corr(method ='spearman')
# Out:
#                 CodeComplexity  BranchCoverage
# CodeComplexity        1.000000       -0.317761
# BranchCoverage       -0.317761        1.000000

# %%
df_clean = df_collection.dropna()

# %%
stats.spearmanr(df_clean['BranchCoverage'], df_clean['CodeComplexity'])
# Out:
# SpearmanrResult(correlation=-0.31776142411161706, pvalue=5.362059420299992e-06)

# %%
print('Statment Coverage '+str((df_collection.LINE_COVERED.sum()/(df_collection.LINE_MISSED.sum() + df_collection.LINE_COVERED.sum()))*100))
# Out:
# Statment Coverage 89.32934643314823

# %%
print('Branch Coverage '+str((df_collection.BRANCH_COVERED.sum()/(df_collection.BRANCH_MISSED.sum() + df_collection.BRANCH_COVERED.sum()))*100))
# Out:
# Branch Coverage 82.72532188841201
