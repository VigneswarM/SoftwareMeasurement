# %%
import pandas as pd

# %%
df_collection = pd.read_csv('jacoco.csv', error_bad_lines=False)

# %%
import matplotlib.pyplot as plt

# %%
df_collection.head()
# Out:
#                   GROUP                            PACKAGE  \
# 0  Apache Commons Codec  org.apache.commons.codec.language
# 1  Apache Commons Codec  org.apache.commons.codec.language
# 2  Apache Commons Codec  org.apache.commons.codec.language
# 3  Apache Commons Codec  org.apache.commons.codec.language
# 4  Apache Commons Codec  org.apache.commons.codec.language
#
#                                           CLASS  INSTRUCTION_MISSED  \
# 0                    MatchRatingApproachEncoder                   0
# 1                               ColognePhonetic                   2
# 2                 ColognePhonetic.CologneBuffer                   0
# 3                                     Metaphone                   4
# 4  DaitchMokotoffSoundex.new Comparator() {...}                   0
#
#    INSTRUCTION_COVERED  BRANCH_MISSED  BRANCH_COVERED  LINE_MISSED  \
# 0                  649              0              76            0
# 1                  502              4              78            1
# 2                   44              0               0            0
# 3                  713             14             146            2
# 4                    9              0               0            0
#
#    LINE_COVERED  COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# 0           114                  0                  51              0
# 1            83                  4                  46              0
# 2            11                  0                   4              0
# 3           166                 14                  87              0
# 4             2                  0                   2              0
#
#    METHOD_COVERED  Statement Coverage  Branch Coverage  Code Complexity
# 0              13          100.000000       100.000000               51
# 1               8           98.809524        95.121951               50
# 2               4          100.000000         0.000000                4
# 3              12           98.809524        91.250000              101
# 4               2          100.000000         0.000000                2

# %%
df_collection.plot(x='Code Complexity', y='Statement Coverage', style='o')

# %%
df_collection.plot(x='Code Complexity', y='Branch Coverage', style='o')

# %%
plt.scatter(df_collection['Code Complexity'], df_collection['Statement Coverage'])
plt.show()

# %%
df_collection.corr(method ='spearman')
# Out:
#                      INSTRUCTION_MISSED  INSTRUCTION_COVERED  BRANCH_MISSED  \
# INSTRUCTION_MISSED             1.000000             0.320194       0.726704
# INSTRUCTION_COVERED            0.320194             1.000000       0.544439
# BRANCH_MISSED                  0.726704             0.544439       1.000000
# BRANCH_COVERED                 0.275694             0.850579       0.589332
# LINE_MISSED                    0.938145             0.325531       0.728960
# LINE_COVERED                   0.325674             0.938253       0.567869
# COMPLEXITY_MISSED              0.916243             0.436748       0.879967
# COMPLEXITY_COVERED             0.269474             0.893964       0.545368
# METHOD_MISSED                  0.792169             0.092506       0.397834
# METHOD_COVERED                 0.257385             0.824219       0.477288
# Statement Coverage            -0.869358            -0.110095      -0.533725
# Branch Coverage               -0.213717             0.500701       0.010407
# Code Complexity                0.461787             0.843390       0.688463
#
#                      BRANCH_COVERED  LINE_MISSED  LINE_COVERED  \
# INSTRUCTION_MISSED         0.275694     0.938145      0.325674
# INSTRUCTION_COVERED        0.850579     0.325531      0.938253
# BRANCH_MISSED              0.589332     0.728960      0.567869
# BRANCH_COVERED             1.000000     0.305735      0.869017
# LINE_MISSED                0.305735     1.000000      0.342860
# LINE_COVERED               0.869017     0.342860      1.000000
# COMPLEXITY_MISSED          0.440154     0.902104      0.461846
# COMPLEXITY_COVERED         0.900906     0.289643      0.931897
# METHOD_MISSED              0.033458     0.792386      0.104107
# METHOD_COVERED             0.762571     0.275009      0.877962
# Statement Coverage        -0.099884    -0.929631     -0.114567
# Branch Coverage            0.677885    -0.169702      0.460808
# Code Complexity            0.872608     0.486731      0.881632
#
#                      COMPLEXITY_MISSED  COMPLEXITY_COVERED  METHOD_MISSED  \
# INSTRUCTION_MISSED            0.916243            0.269474       0.792169
# INSTRUCTION_COVERED           0.436748            0.893964       0.092506
# BRANCH_MISSED                 0.879967            0.545368       0.397834
# BRANCH_COVERED                0.440154            0.900906       0.033458
# LINE_MISSED                   0.902104            0.289643       0.792386
# LINE_COVERED                  0.461846            0.931897       0.104107
# COMPLEXITY_MISSED             1.000000            0.425405       0.701316
# COMPLEXITY_COVERED            0.425405            1.000000       0.070570
# METHOD_MISSED                 0.701316            0.070570       1.000000
# METHOD_COVERED                0.386438            0.944326       0.104210
# Statement Coverage           -0.799883           -0.069505      -0.824954
# Branch Coverage              -0.121400            0.537796      -0.222404
# Code Complexity               0.616426            0.934753       0.269385
#
#                      METHOD_COVERED  Statement Coverage  Branch Coverage  \
# INSTRUCTION_MISSED         0.257385           -0.869358        -0.213717
# INSTRUCTION_COVERED        0.824219           -0.110095         0.500701
# BRANCH_MISSED              0.477288           -0.533725         0.010407
# BRANCH_COVERED             0.762571           -0.099884         0.677885
# LINE_MISSED                0.275009           -0.929631        -0.169702
# LINE_COVERED               0.877962           -0.114567         0.460808
# COMPLEXITY_MISSED          0.386438           -0.799883        -0.121400
# COMPLEXITY_COVERED         0.944326           -0.069505         0.537796
# METHOD_MISSED              0.104210           -0.824954        -0.222404
# METHOD_COVERED             1.000000           -0.064545         0.384492
# Statement Coverage        -0.064545            1.000000         0.244772
# Branch Coverage            0.384492            0.244772         1.000000
# Code Complexity            0.876972           -0.275779         0.457492
#
#                      Code Complexity
# INSTRUCTION_MISSED          0.461787
# INSTRUCTION_COVERED         0.843390
# BRANCH_MISSED               0.688463
# BRANCH_COVERED              0.872608
# LINE_MISSED                 0.486731
# LINE_COVERED                0.881632
# COMPLEXITY_MISSED           0.616426
# COMPLEXITY_COVERED          0.934753
# METHOD_MISSED               0.269385
# METHOD_COVERED              0.876972
# Statement Coverage         -0.275779
# Branch Coverage             0.457492
# Code Complexity             1.000000

# %%
df_collection[['Code Complexity','Statement Coverage']].corr(method ='spearman')
# Out:
#                     Code Complexity  Statement Coverage
# Code Complexity            1.000000           -0.275779
# Statement Coverage        -0.275779            1.000000

# %%
df_collection[['Code Complexity','Branch Coverage']].corr(method ='spearman')
# Out:
#                  Code Complexity  Branch Coverage
# Code Complexity         1.000000         0.457492
# Branch Coverage         0.457492         1.000000
